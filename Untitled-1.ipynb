# %%
# %pip install opencv-contrib-python numpy pytesseract opencv-python pillow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.6/32.6 MB 22.8 MB/s  0:00:01 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 21.3 MB/s  0:00:00m0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pytesseract] [opencv-python]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # label image

# %%
#!/usr/bin/env python3
"""
Character Recognition using Tesseract OCR.
Covers full ASCII: letters, digits, punctuation, symbols.
"""

import sys
import cv2
import numpy as np
import pytesseract
from PIL import Image


def preprocess(image: np.ndarray) -> np.ndarray:
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    denoised = cv2.fastNlMeansDenoising(gray, h=10)
    _, binary = cv2.threshold(denoised, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    return binary


def recognize(image_path: str) -> str:
    image = cv2.imread(image_path)
    if image is None:
        raise FileNotFoundError(f"Could not load image: {image_path}")

    processed = preprocess(image)
    pil_image = Image.fromarray(processed)

    config = "--oem 3 --psm 6"

    text = pytesseract.image_to_string(pil_image, config=config)
    return text.strip()

# %%
text = recognize("/Users/jamesparkinson/Desktop/Screenshot 2026-05-03 at 21.36.22.png")
print(f"Detected characters: {text}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 text = recognize("/Users/jamesparkinson/Desktop/Screenshot 2026-05-03 at 21.36.22.png")
#       2 print(f"Detected characters: {text}")
#
# Cell In[14], line 38, in recognize(image_path)
#      34         r"ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz"
#      35         r"0123456789 !#$%&'()*+,-./:;<=>?@[\]^_`{|}~"
#      36     )
#      37
# ---> 38     text = pytesseract.image_to_string(pil_image, config=config)
#      39     return text.strip()
#
# File ~/.venvs/python314/lib/python3.14/site-packages/pytesseract/pytesseract.py:486, in image_to_string(image, lang, config, nice, output_type, timeout)
#     481 """
#     482 Returns the result of a Tesseract OCR run on the provided image to string
#     483 """
#     484 args = [image, 'txt', lang, config, nice, timeout]
# --> 486 return {
# ...
